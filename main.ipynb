# %% [markdown]
# <div style="display: flex; justify-content: center;">
#     <img src="./image_notebook/header_image.png">
# </div>
#
# <h3>
#     <center>
#         Міністерство освіти і науки, молоді та спорту<br>
#         України Національний технічний університет<br>
#         України "Київський політехнічний інститут імені<br>
#         Ігоря Сікорського" Фізико - технічний інститут
#     </center>
# </h3>
#
#
# <br>
# <br>
# <br>
# <br>
#
# <h3>
#     <center>
#         Курсова робота<br>
#         Аналіз даних за допомогою Python та бібліотеки Pandas<br>
#     </center>
# </h3>
#
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
#
# <h4 style="text-align: right;">
#     Виконала:<br>
#     Студентка групи ФІ-21, НН ФТІ<br>
#     Литвин Аліна<br>
#     Перевірив:<br>
#     Павлюк Андрій Дмитрович<br>
# </h4>
#
#
#
#
#
#
#
#
#
#
#
# <h3>
#     <center>
#         Київ 2023
#     </center>
# </h3>

# %% [markdown]
# <center>
#     <h1>
#         <b>Частина перша</b>
#     </h1>
# </center>
#
# <h2>Знайомство з можливостями Anaconda/IPython
# Notebook</h2><br>
#
# <span style="font-size:22px;">
#     <strong>Мета:</strong> Вивчення основних принципів роботи та використання програмних
# компонентів <em>Anaconda</em>. <strong>Інсталяція.</strong> Дослідження можливостей <em>IPython
# Notebook</em>. Підготовка розділу 1 пояснювальної записки про зроблену
# роботу — опис інсталяції, можливостей використання та їх ілюстрація.
# </span>

# %% [markdown]
# <p>
#     <span style="font-size:18px;">
#     <u>Ipython Notebook</u> — це середовище розробки, що дає можливості для
#     інтерактивної та ітеративної розробки проектів, пов’язаних з Data Science.
#     Notebook інтегрує код та результати його виконання в один файл разом з
#     графіками, текстом, математичними виразами та іншими можливими видами
#     представлення інформації.
#     </span>
# </p>
#
# <p>
#     <span style="font-size:18px;">
#     <u>Ipython Notebook</u> – неймовірно потужний інструмент для інтерактивної розробки
#     та подання проектів в області наук про дані. Це зручний інструмент для створення
#     аналітичних звітів, що дозволяє одночасно зберігати разом код, формули,
#     зображення, коментарі, результати і графіки.
#     </span>
# <p>
#
# <p>
#     <span style="font-size:18px;">
#     <u>Блокнот (notebook)</u> представляє код і результат його виведення в єдиному
#     документі, який об’єднує візуалізацію, розмічений текст, математичні рівняння та
#     інші мультимедійні дані. Цей інтуїтивно зрозумілий робочий процес сприяє
#     ітеративній і швидкій розробці, що робить ноутбуки все більш популярним
#     вибором для подання даних і їх аналізу. Notebook інтегрує код та результати його
#     виконання в один файл разом з графіками, текстом, математичними виразами та
#     іншими можливими видами представлення інформації.
# </p>

# %% [markdown]
# <h4>
#     <b>Інсталяція:</b>
# </h4>
# <div style="display: block;">
#     <span>1. З сайту <a href="https://www.anaconda.com/products/distribution">https://www.anaconda.com/products/distribution</a> завантажте Anaconda</span><br>
#     <img src="./image_notebook/0.jpg"><br><br>
# </div>
# <div style="display: block;">
#     <span>2. Після завантаження запускаємо Anaconda Navigator:</span>
#     <img src="./image_notebook/1.jpg"><br><br>
# </div>
# <div style="display: block;">
#     <span>3. Натискаємо «Install» під Jupyter Notebook. Так як у мене вже інстальовано, то присутня кнопка «Launch»</span>
#     <img src="./image_notebook/2.jpg"><br><br>
# </div>
# <div style="display: block;">
#     <span>4. Після завантаженні ми вже можемо працювати в Jupyter Notebook, натиснувши Launch.</span>
#     <img src="./image_notebook/3.jpg"><br>
# </div>

# %% [markdown]
# <h4>
#     <b>Можливості Jupyter Notebook:</b>
# </h4>
# <div>
#     <ul>
#         <li>
#             Інтерактивне виконання коду: можна запускати фрагменти Python коду, переглядати результати, змінювати код і перезапускати
#             <br>
#             <br>
#             <img src="./image_notebook/image_01.png" />
#             <br>
#             <img src="./image_notebook/image_02.png" />
#             <br>
#             <img src="./image_notebook/image_03.png" />
#         </li>
#         <li>
#             Візуалізація даних за допомогою Matplotlib, Seaborn та інших бібліотек
#             <br>
#             <br>
#             <img src="./image_notebook/image_04.png" />
#             <br>
#             <img src="./image_notebook/image_05.png" />
#             <br>
#             <img src="./image_notebook/image_06.png" />
#         </li>
#         <li>
#             Поєднання коду, тексту, графіків, рівнянь в одному документі
#             <br>
#             <br>
#             <img src="./image_notebook/image_07.png" />
#             <br>
#             <img src="./image_notebook/image_08.png" />
#         </li>
#         <li>
#             Експорт та імпорт документів в різні формати (HTML, PDF, Python script)
#             <br>
#             <br>
#             <img src="./image_notebook/image_09.png" />
#         </li>
#         <li>Вбудована система версіонування коду</li>
#         <li>Можливість спільної роботи - додавання коментарів, спільний доступ до ноутбуків</li>
#         <li>Підтримка великих обсягів даних та обчислень</li>
#         <li>Розширюваність за допомогою додаткових пакетів і бібліотек</li>
#         <li>Підтримує кілька типів розмітки Markdown\HTML\LaTex</li>
#     </ul>
# </div>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>Про Markdown розмітку</b>
#     </h2>
#     <br>
#     <br>
#     <span>
#         Вкиористовується для створення зручного і цікавого інтерфейсу документ. Користувач може створювати і редагувати кожний доступний елемент звичайного документу, тобто: зголовки, тексти, списки, посилання та мультимедія (а також багато іншого). Для цього використовується спеціальна Markdown розмітка, але також можно використовувати і спеціальні теги (HTML) для розмітки. Наприклад для створення заголовка нам потрібно використовувати символ - решітка (якщо markdown), а якщо використовуючи теги - h(та вказати рівень заголовку, він може бути від 1 до 6).
#     </span>
# </div>

# %% [markdown]
# <div>
#     <h2>
#         <b>Заголовки</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад Markdown розмітки:</b>
#     </span>
#     <br>
#     # Заголовок 1-го рівня
#     <br>
#     ## Заголовок 2-го рівня
#     <br>
#     ### Заголовок 3-го рівня
#     <br>
#     #### Заголовок 4-го рівня
#     <br>
#     ##### Заголовок 5-го рівня
#     <br>
#     ###### Заголовок 6-го рівня
# </div>

# %% [markdown]
# <div>
#     <h2>
#         <b>Заголовки</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад розмітки заа допмогою тегів:</b>
#     </span>
# </div>

# %% [markdown]
# ```html
# <h1>Заголовок 1-го рівня</h1>
# <h2>Заголовок 2-го рівня</h2>
# <h3>Заголовок 3-го рівня</h3>
# <h4>Заголовок 4-го рівня</h4>
# <h5>Заголовок 5-го рівня</h5>
# <h6>Заголовок 6-го рівня</h6>
# ```

# %% [markdown]
# <div>
#     <h1>Заголовок 1-го рівня</h1>
#     <h2>Заголовок 2-го рівня</h2>
#     <h3>Заголовок 3-го рівня</h3>
#     <h4>Заголовок 4-го рівня</h4>
#     <h5>Заголовок 5-го рівня</h5>
#     <h6>Заголовок 6-го рівня</h6>
# </div>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>Текст</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад markdown:<b>
#     </span>
#     <br>
#     Простий текст
#     <br>
#     *Курсивний текст*
#     <br>
#     **Жирний текст**
# </div>

# %% [markdown]
# <div>
#     <h2>
#         <b>Текст</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад за допомогою тегів:<b>
#     </span>
# </div>

# %% [markdown]
# ```html
# <span>Простий текст</span>
# <b>Жирний текст</b>
# <i>Курсивний текст</i>
# <u>Підкреслений текст</u>
# ```

# %% [markdown]
# <span>Простий текст</span>
# <b>Жирний текст</b>
# <i>Курсивний текст</i>
# <u>Підкреслений текст</u>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>Списки</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад markdown розмітки на різні списки:<b>
#     </span>
#     <br>
#     <span>
#         <b>Маркований список:<b>
#     </span>
#     <br>
#     <br>
#     - Купити хліб
#     <br>
#     - Прибрати
#     <br>
#     - Написати домашки
#     <br>
#     <br>
#     <span>
#         <b>Нумерований список:<b>
#     </span>
#     <br>
#     <br>
#     1. Купити хліб
#     <br>
#     2. Прибрати
#     <br>
#     3. Написати домашки
# </div>

# %% [markdown]
# <div>
#     <h2>
#         <b>Списки</b>
#     </h2>
#     <br>
#     <span>
#         <b>Приклад створення списків за допомогою тегів:<b>
#     </span>
# </div>

# %% [markdown]
# ```html
# <ul>
#     <li>Написати хліб</li>
#     <li>Прибрати домашки</li>
#     <li>Купити...</li>
# </ul>
#
# <ol>
#     <li>Купити домашки</li>
#     <li>Прибрати хліб</li>
#     <li>Написати...</li>
# </ol>
# ```

# %% [markdown]
# <div>
#     <ul>
#         <li>Написати хліб</li>
#         <li>Прибрати домашки</li>
#         <li>Купити...</li>
#     </ul>
#     <br>
#     <ol>
#         <li>Купити домашки</li>
#         <li>Прибрати хліб</li>
#         <li>Написати...</li>
#     </ol>
# </div>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>Інші засоби та елементи форматування документу:</b>
#     </h2>
#     <br>
#     <br>
#     <span>Існують і інші засоби, які допомогають зручно форматувати документ, напариклад: вставки коду, цитатні блоки, розмежуваальна лінія та інше.</span>
#     <br>
#     <span>Наприклад:</span>
#     <br>
#     --- (створює розмежувальну лінію)
#     <br>
#     > Цитатний блок номер 1
#     <br>
#     ```Python
#     <br>
#     print("Enter card number: ")
#     <br>
#     ```
#     <br>
#     <br>
#     <span>Також можна використовувати теги:</span>
# </div>

# %% [markdown]
# ```html
# <hr> - розмежувальна лінія
# <blockquote>Цитата номер 1: Якщо поїв гречку - помий таарілку.</blockquote>
# <code>
# print("Enter card number: ")
# </code>
# ```

# %% [markdown]
# <hr>
# <blockquote>Цитата номер 1: Якщо поїв гречку - помий таарілку.</blockquote>
# <code>
# print("Enter card number: ")
# </code>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>Медіа контент</b>
#     </h2>
#     <br>
#     <br>
#     <span>Наприклад:</span>
#     <br>
#     <span>Зовнішнє: [посилання](повна_юрл_адреса)</span>
#     <br>
#     <span>Внутрішнє: [посилання](#id_певного_розділу_документу)</span>
#     <br>
#     <br>
#     <span>А що якщо за допомогою тегів?:</span>
# </div>

# %% [markdown]
# ```html
# <a href="#id_розділу_номер_один">Розділ номер 1: Як варити макароні?</a>
# <a href="посилання_на_сайт">Продам авто</a>
# ```

# %% [markdown]
# <a href="#id_розділу_номер_один">Розділ номер 1: Як варити макароні?</a><br>
# <a href="посилання_на_сайт">Продам авто</a>

# %% [markdown]
# <h2>
#     <b>Або наприклад можемо додати якісь зображення: </b>
# </h2>
# <br>
# <br>
# <span>Наприклад:</span>
# <br>
# <br>

# %% [markdown]
# ```HTML
# <img src="./image_notebook/image_12.png" />
# ```

# %% [markdown]
# <div>
# <img src="./image_notebook/image_12.png" />
# </div>

# %% [markdown]
# <hr>
# <br>
# <div>
#     <h2>
#         <b>LaTex форматування</b>
#     </h2>
#     <br>
#     <br>
#     <span>Наприклад:</span>
#     <br>
#     <br>
#     <img src="./image_notebook/image_11.png" />
# </div>

# %% [markdown]
# $$
# \bar{X_{std}} = \frac{1}{\sigma} (X - \mu)
# $$
#
# $$
# \mu = \sum p_i X_i  {-де  p_i-ймовірність \hspace{0.25cm} появи \hspace{0.25cm} елементу X_i}
# $$
#
# $$
# \sigma = \sqrt{\frac{\sum_{}{} (X_i - \bar{X})}{n-1}}
# $$

# %% [markdown]
# <hr>
# <center>
#     <h1>
#         <b>Частина друга</b>
#     </h1>
# </center>
# <span>Виконання та підготовка розділу 2 пояснювальної записки.</span>
# <br>
# <br>
# <span>
#     <b>Мета:</b> Отримати досвід використання основних засобів аналізу та візуалізації даних у середовищі IPython Notebook на модельних наборах даних.
# </span>
# <br>
# <br>
# <span>
#     <b>Вступ:</b> В даній частині я попрактикувалась в маніпуляції з наборами даних, які обирала сама, використовуючи сайт <a href="https://www.kaggle.com/">Kaggle.com</a>. <br>Я змогла знайти для себе дійсно цікавий набір даних - про криптовалюту, а саме зміну цін за певними датами. Мій датасет: Cryptocurrency Historical Prices - <a href="https://www.kaggle.com/datasets/sudalairajkumar/cryptocurrencypricehistory">https://www.kaggle.com/datasets/sudalairajkumar/cryptocurrencypricehistory</a>.
# </span>
# <span>
#
# </span>

# %% [markdown]
# <h4>Імпортуємо бібліотеки, які нам потрібні для роботи</h4>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os

# %%
options = [
    "Aave", 
    "BinanceCoin", 
    "Bitcoin", 
    "Cardano", 
    "ChainLink", 
    "Cosmos", 
    "CryptocomCoin", 
    "Dogecoin", 
    "EOS", 
    "Ethereum", 
    "Iota", 
    "Litecoin", 
    "Monero", 
    "NEM", 
    "Polkadot", 
    "Solana", 
    "Stellar", 
    "Tether", 
    "Tron", 
    "Uniswap", 
    "USDCoin", 
    "WrappedBitcoin", 
    "XRP"
]

# %%
def formating_data(options, year):
    result = pd.DataFrame()
    filename = f'format_data/cryptocurrency_data_by_{year}_year.csv'

    for option in options:
        df = pd.read_csv(f'csv_data/coin_{option}.csv')
        
        # фільтруємо по року
        mask = df['Date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S").year) == year
        filtered_df = df[mask]
        
        result = pd.concat([result, filtered_df])
        

    if os.path.exists(filename):
        print(f"File {filename} already exists. Skipping!")
    else:
        result.to_csv(f'format_data/cryptocurrency_data_by_{year}_year.csv', index=False)

# %%
formating_data(options=options, year=2019)
formating_data(options=options, year=2020)
formating_data(options=options, year=2021)
# Out:
# File format_data/cryptocurrency_data_by_2019_year.csv already exists. Skipping!
# File format_data/cryptocurrency_data_by_2020_year.csv already exists. Skipping!
# File format_data/cryptocurrency_data_by_2021_year.csv already exists. Skipping!

# %% [markdown]
# ---
# ### **Завдання №1**
# #### **Завдання:** <br>Встановити IPython Notebook разом з Anaconda та створити новий IPython Notebook 3/2
# #### **Виконання:**<br>Мною був створенний цей Jupyter Notebook, також інстальована і налаштована Anaconda Environment. В цьому документі описана моя курсова робота, яка націлена на аналіз і роботу з даними ринку криптовалюти. Це допоможе зорієнтуватись по минулим і теперішнім цінам, і, за допомогою діаграм вираховувати майбутню ціну для кожної з валют.

# %% [markdown]
# ---
# ### **Завдання №2**
# #### **Завдання:**<br>Проаналізувати набір даних на наявність пропущених значень та NaN.<br>У випадку наявності таких значень їх потрібно заповнити значеннями за допомогою fillna, використовуючи метод bfill (заміна на наступне валідне значення після Nan) або ffil (заміна на попереднє валідне значення після Nan)
# #### **Виконання:**

# %%
year_of_data = int(input("Enter year for work with data: "))
dataframe = pd.read_csv(f'format_data/cryptocurrency_data_by_{year_of_data}_year.csv', index_col='Name')
# Out:
# Enter year for work with data: 2020

# %%
is_null = dataframe.isnull().values.any()
null_list = dataframe.isnull().sum()
print(f"Чи існують пусті значення: {is_null}.\nСписок до чистики: \n{null_list}")
# Out:
# Чи існують пусті значення: False.
# Список до чистики:
# SNo          0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
cleaned_df = dataframe.ffill()
print(f"Список після чистки:\n{cleaned_df.isnull().sum()}")
# Out:
# Список після чистки:
# SNo          0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %% [markdown]
# ---
# ### **Завдання №3**
# #### **Завдання:**<br>Відкрити набір даних засобами pandas.<br>
# ```Python
# df = pd.read_csv(path)
# df = pd.read_excel(path)
# ```
# #### **Виконання:**

# %%
dataframe = pd.read_csv(f'format_data/cryptocurrency_data_by_{year_of_data}_year.csv', index_col='Name')
dataframe.head(20)
# Out:
#       SNo Symbol                 Date       High        Low       Open  \
# Name
# Aave    1   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# Aave    2   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# Aave    3   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# Aave    4   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# Aave    5   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
# Aave    6   AAVE  2020-10-10 23:59:59  51.405655  46.703328  46.818146
# Aave    7   AAVE  2020-10-11 23:59:59  51.453374  48.716040  49.133130
# Aave    8   AAVE  2020-10-12 23:59:59  54.421418  48.754077  49.661573
# Aave    9   AAVE  2020-10-13 23:59:59  57.481904  49.598735  52.238392
# Aave   10   AAVE  2020-10-14 23:59:59  57.853946  49.629529  51.372899
# Aave   11   AAVE  2020-10-15 23:59:59  52.080685  44.018325  51.387610
# Aave   12   AAVE  2020-10-16 23:59:59  43.906730  39.142957  42.890607
# ...

# %% [markdown]
# ---
# ### **Завдання №4**
# #### **Завдання:**<br>Представити його у матричному вигляді. Відобразити 10 елементів для 4-ох ознак Виділити зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти елементів.<br>Приклад візуалізації:

# %% [markdown]
# <table width="60%" style="text-align: center;">
#             <tr>
#                 <th style="color: grey; font-style: italic; text-align: right;">Model: </th>
#                 <th colspan="2" style="background: #0c0a6e; color: white;">Decision Tree</th>
#                 <th colspan="2" style="background: #0c0a6e; color: white;">Regression</th>
#             </tr>
#             <tr style="text-align: center;">
#                 <td style="color: grey; font-style: italic; text-align: right;">Predicted:</td>
#                 <td style="background: #0c0a6e; color: white;">Tomour</td>
#                 <td style="background: #0c0a6e; color: white;">Non Tomour</td>
#                 <td style="background: #0c0a6e; color: white;">Tomour</td>
#                 <td style="background: #0c0a6e; color: white;">Non Tomour</td>
#             </tr>
#             <tr>
#                 <td style="color: grey; font-style: italic; text-align: right;">Actual Label:</td>
#                 <td style="background: #0c0a6e; color: white;"> </td>
#                 <td style="background: #0c0a6e; color: white;"> </td>
#                 <td style="background: #0c0a6e; color: white;"> </td>
#                 <td style="background: #0c0a6e; color: white;"> </td>
#             </tr>
#             <tr>
#                 <td style="background: #0c0a6e; color: white; text-align: right;">Tomour</td>
#                 <td style="background: #9dff96; color: black;">38</td>
#                 <td style="background: #ffa6a6; color: black;">2</td>
#                 <td style="background: #9dff96; color: black;">18</td>
#                 <td style="background: #ffa6a6; color: black;">22</td>
#             </tr>
#             <tr>
#                 <td style="background: #0c0a6e; color: white; text-align: right;">Non Tomour</td>
#                 <td style="background: #ffa6a6; color: black;">19</td>
#                 <td style="background: #9dff96; color: black;">439</td>
#                 <td style="background: #ffa6a6; color: black;">6</td>
#                 <td style="background: #9dff96; color: black;">452</td>
#             </tr>
#         </table>

# %% [markdown]
# #### **Виконання:**

# %%
selected_dataframe = dataframe.iloc[:10, 3:7]
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

def highlight_min(s):  
    is_min = s == s.min()
    return ['background-color: red' if v else '' for v in is_min]

selected_dataframe = selected_dataframe.reset_index(drop=True) 
styled_df = selected_dataframe.style.apply(highlight_max).apply(highlight_min)
styled_df
# Out:
# <style type="text/css">
# #T_6d6c4_row0_col1, #T_6d6c4_row0_col3, #T_6d6c4_row1_col2, #T_6d6c4_row9_col0 {
#   background-color: green;
# }
# #T_6d6c4_row2_col0, #T_6d6c4_row2_col1, #T_6d6c4_row2_col3, #T_6d6c4_row3_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_6d6c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d6c4_level0_col0" class="col_heading level0 col0" >High</th>
#       <th id="T_6d6c4_level0_col1" class="col_heading level0 col1" >Low</th>
#       <th id="T_6d6c4_level0_col2" class="col_heading level0 col2" >Open</th>
#       <th id="T_6d6c4_level0_col3" class="col_heading level0 col3" >Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d6c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d6c4_row0_col0" class="data row0 col0" >55.112358</td>
#       <td id="T_6d6c4_row0_col1" class="data row0 col1" >49.787900</td>
# ...

# %% [markdown]
# ### **Додатково:**
# #### Вирахувати математичне сподівання та дисперсію для набору даних. Стандартизувати дані.
#
# $X_{\text{std}}=\frac{X-\mu}{\sigma}$
# <br>
# <br>
# $\mu=\Sigma$ $\qquad $ $p_{\text{i}}X_{\text{i}},~{\text{де}} ~ p_{\text{i}}-{\text{ймовірність появи елементу}} X_{\text{i}}$
# <br>
# <br>
# $\sigma=\sqrt{\frac{\Sigma\quad(X_{\text{i}} - \underline{X})}{n - 1}}$

# %%
selected_data = dataframe.iloc[:, 3:7]

mean = selected_data.mean()
std = selected_data.std()
variance = np.var(selected_data)
standardized = (selected_data - mean) / std

print(f"Математичне сподівання для вибраних даних:\n{mean}")
print(f"\nДисперсія для вибраних даних:\n{variance}")
print(f"\nСтандартне відхилення для вибраних даних:\n{std}")
print(f"\nСтандартизовані вибрані дані:\n{standardized.iloc[:10]}")
# Out:
# Математичне сподівання для вибраних даних:
# High     1125.797921
# Low      1075.109325
# Open     1098.013431
# Close    1103.912397
# dtype: float64
#
# Дисперсія для вибраних даних:
# High     1.306202e+07
# Low      1.188663e+07
# Open     1.238765e+07
# Close    1.258408e+07
# dtype: float64
#
# Стандартне відхилення для вибраних даних:
# High     3614.381029
# Low      3447.927581
# Open     3519.842211
# Close    3547.639313
# dtype: float64
#
# Стандартизовані вибрані дані:
#           High       Low      Open     Close
# Name
# Aave -0.296229 -0.297373 -0.296984 -0.296167
# Aave -0.296702 -0.299999 -0.296809 -0.299216
# Aave -0.299744 -0.301381 -0.299904 -0.299869
# Aave -0.299054 -0.301170 -0.300618 -0.298832
# Aave -0.298316 -0.299257 -0.299516 -0.297971
# Aave -0.297255 -0.298268 -0.298648 -0.297318
# Aave -0.297242 -0.297684 -0.297991 -0.297170
# Aave -0.296420 -0.297673 -0.297841 -0.296443
# Aave -0.295574 -0.297428 -0.297108 -0.296757
# ...

# %% [markdown]
# ---
# ### **Завдання №5**
# #### **Завдання:**<br>Провести візуалізацію даних. Для цього необхідно побудувати такі типи графіків: Line Plot, Bar Chart, Histogram, Heatmap.
# ```Python
# import seaborn as sns
# sns.lineplot(data)
# sns.barplot(x, y)
# sns.heatmap(data)
# sns.histplot(data)
# ```
# ### **Виконання:**

# %%
plt.figure(figsize=(10, 6))
heat_data = dataframe.iloc[:20, 4:8].corr()

print(f"Кореляція:\n{heat_data}")
sns.heatmap(data=heat_data, cmap='crest', annot=True, linewidth=.5, fmt=".2f")

plt.ylabel('Ціна, $')
plt.title('Різні позиції цін на валюти')
plt.show()
# Out:
# Кореляція:
#            High       Low      Open     Close
# High   1.000000  0.938087  0.946044  0.914445
# Low    0.938087  1.000000  0.883997  0.952591
# Open   0.946044  0.883997  1.000000  0.801046
# Close  0.914445  0.952591  0.801046  1.000000

# %%
plt.figure(figsize=(10, 6))

data = dataframe
data.reset_index(inplace=True)
data = data[data['Name'] == 'Dogecoin']
data = data.iloc[:30]

sns.lineplot(data=data, x='Date', y='High', style="Name", markers=True, dashes=False)
plt.xlabel('Дата')
plt.ylabel('Найвища ціна, $')
plt.xticks(rotation=90)
plt.title('Найвища ціна за день')
plt.show()

# %%
plt.figure(figsize=(10, 6))

crypto_df = dataframe[~dataframe['Name'].isin(['Bitcoin', 'Wrapped Bitcoin', 'Ethereum'])]

ax = sns.barplot(data=crypto_df, x='Name', y='Low')
ax.bar_label(ax.containers[0], fontsize=10)

plt.xlabel('Дата')
plt.ylabel('Найнижча ціна, $')
plt.xticks(rotation=90)
plt.title('Найнижча ціна за день')
plt.show()

# %%
plt.figure(figsize=(10, 6))

btc_df = dataframe[dataframe['Name'].isin(['Bitcoin', 'Wrapped Bitcoin', 'Ethereum'])]

ax = sns.barplot(data=btc_df, x='Name', y='Low')
ax.bar_label(ax.containers[0], fontsize=10)

plt.xlabel('Дата')
plt.ylabel('Найнижча ціна, $')
plt.xticks(rotation=90)
plt.title('Найнижча ціна за день')
plt.show()

# %%
plt.figure(figsize=(10, 6))

selected_data = dataframe[dataframe['Date'] == '2020-10-05 23:59:59']
crypto_df = selected_data[~selected_data['Name'].isin(['Bitcoin', 'Wrapped Bitcoin', 'Ethereum'])]
sns.histplot(data=crypto_df, x='Close', bins=30)
    
plt.xlabel('Ціна на укладанні угоди')
plt.xticks(rotation=90)
plt.title('Гістограма цін на укладанні угоди')
plt.show()

# %% [markdown]
# ---
# ### **Завдання №6**
# #### **Завдання:**<br>Збудувати лінійний графік з 4-ма лініями, які взяті з ознак та додати annotate для середнього значення кожної лінії. При цьому для візуалізації багатовимірних даних з кількістю ознак більше двох обов’язково необхідно за допомогою subplot збудувати 9 графіків задопомогою комбінування різних ознак.
# ### **Виконання:**

# %%
plt.figure(figsize=(10, 6))
fig, ax = plt.subplots()

data = dataframe
data.reset_index(inplace=True)
crypto_df = selected_data[~selected_data['Name'].isin(['Bitcoin', 'Wrapped Bitcoin', 'Ethereum'])]

for column in ['High','Low','Open','Close']:
    ax.plot(crypto_df['Name'], crypto_df[column], label=column)

ax.legend()

y_values = crypto_df[data.columns[6:10]].mean().values
x_values = crypto_df['Name'].unique()

for x, y in zip(x_values, y_values):
    ax.annotate(f"{y:.2f}", xy=(x, y), xytext=(5, 5), textcoords='offset points') 
        
ax.autoscale()
plt.xticks(rotation=90)
plt.show()

# %%
data = dataframe.iloc[:400, 5:9]
sns.pairplot(data=data)
plt.show()
# Out:
# /home/alina/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ---
# ### **Завдання №7**
# #### **Завдання:**<br>Вирахувати коефіцієнт пірсона для кожної пари ознак.
# ```Python
# df.corr(method='pearson')
# ```
# #### Взяти третю ознаку за вісь X та збудувати relplot для двох ознак, що мають найбільшу кореляцію за допомогою бібліотеки seaborn.
# ```Python
# sns.replot(data)
# ```
# ### **Виконання:**

# %%
pearson_corr = dataframe.iloc[:, 5:9].corr(method='pearson') 
print(f"Коефіцієнт пірсона:\n{pearson_corr}")

x_col = dataframe.columns[6]
y_cols = pearson_corr.idxmax().index

sns.relplot(data=dataframe, x=x_col, y=y_cols[0], hue=y_cols[1], kind="scatter")
    
plt.xlabel(x_col)
plt.ylabel(y_cols[0])
plt.title('Relplot')
plt.show()
# Out:
# Коефіцієнт пірсона:
#            High       Low      Open     Close
# High   1.000000  0.999458  0.999584  0.999633
# Low    0.999458  1.000000  0.999671  0.999737
# Open   0.999584  0.999671  1.000000  0.999363
# Close  0.999633  0.999737  0.999363  1.000000
# /home/alina/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ---
# ### **Завдання №8**
# #### **Завдання:**<br>У початковому наборі даних, перед заміною значень Nan на валідні значення за допомогою fillna, необхідно видалити всі колонки із значеннями Nan.
# ```Python
# df.dropna()
# ```
# ### **Виконання:**

# %%
dataframe = pd.read_csv(f'format_data/cryptocurrency_data_by_{year_of_data}_year.csv')
print(f"До заміни:\n{dataframe.isnull().sum()}")
# Out:
# До заміни:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
dataframe = dataframe.ffill()
print(f"Після заміни:\n{dataframe.isnull().sum()}")
# Out:
# Після заміни:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
dataframe.head(20)
# Out:
#     SNo  Name Symbol                 Date       High        Low       Open  \
# 0     1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# 1     2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# 2     3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# 3     4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# 4     5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
# 5     6  Aave   AAVE  2020-10-10 23:59:59  51.405655  46.703328  46.818146
# 6     7  Aave   AAVE  2020-10-11 23:59:59  51.453374  48.716040  49.133130
# 7     8  Aave   AAVE  2020-10-12 23:59:59  54.421418  48.754077  49.661573
# 8     9  Aave   AAVE  2020-10-13 23:59:59  57.481904  49.598735  52.238392
# 9    10  Aave   AAVE  2020-10-14 23:59:59  57.853946  49.629529  51.372899
# 10   11  Aave   AAVE  2020-10-15 23:59:59  52.080685  44.018325  51.387610
# ...

# %% [markdown]
# ---
# ### **Завдання №9**
# #### **Завдання:**<br>Видалити також випадкові значення з ознак що мають найбільшу кореляцію у кількості 10% для обох. Підрахувати кореляцію. Збудувати multipple scatterplot за допомогою FacetGrid для цих оновлених ознак використовуючи бібліотеку seaborn взявши третю ознаку за вісь x.
# ```Python
# g = sns.FaceGrid(tops, col="sex", hue="smoker")
# g.map(sns.scatterplot, "total_bill", "tip", alpha=.7)
# g.add_legend()
# ```
# ### **Виконання:**

# %%
df_with_10 = dataframe.drop(['Name'], axis=1)
df_without_10 = df_with_10.iloc[np.random.choice(df_with_10.shape[0], round(df_with_10.shape[0] * 0.9))]

numeric_columns = df_with_10.select_dtypes(include=['float64']).columns
df_with_10_numeric = df_with_10[numeric_columns]
df_without_10_numeric = df_without_10[numeric_columns]

plt.scatter("High", "Low", data=df_without_10_numeric.iloc[:100, :])
plt.xlabel("High")
plt.ylabel("Low")
plt.legend()
plt.show()

# %% [markdown]
# <h2>
#     <b>Висновки</b>
# </h2>
# <h4>
#     У цій курсовій роботі я навчилась встановлювати і працювати з Jupyter Notebook, а також дистрибутивом Anaconda, керувати пакетами та встановлювати їх. Навчилась використовувати і працювати з графіками, великими даними, формувати нові таблички з інших табличок. Стандартизувати дані, видаляти пусті значення та візуалізувати їх.
#     <br>
#     <br>
#     Результат та вихідний код прикріплюю до цього GitHub: <a href="https://github.com/Alinalitvinn/course-sprog">CryptoCurrency Course-Work</a>
# </h4>

# %% [markdown]
# ## **Джерела використанної літератури**
# 1. Офіційна документація Pandas: https://pandas.pydata.org/docs/getting_started/index.html
# 2. Офіційна документація Seaborn: https://seaborn.pydata.org/
# 3. Офіційна документація Numpy: https://numpy.org/
# 4. Офіційна документація Anaconda: https://docs.anaconda.com/index.html
# 5. Офіційна документація Jupyter Notebook: https://docs.jupyter.org/en/latest/
